# %%
# !pip install torch torchtext torchvision sentencepiece
# !pip install torchserve torch-model-archiver
# !pip install nvgpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.3 MB 20.2 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.6 MB 198 kB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 66 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 46 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.6 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install colab_ssh --upgrade

# from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
# launch_ssh_cloudflared(password="cow")

NGROK_TOKEN = '2GkkqGcHUsj7WQh0wfjjp4XyD8q_6xMwdyVh5raU8D46rFqSH'
PASSWORD = 'cow'
from colab_ssh import launch_ssh
launch_ssh(NGROK_TOKEN,PASSWORD)


# r = requests.get('http://localhost:4040/api/tunnels')
# str_ssh = r.json()['tunnels'][0]['public_url']
# str_ssh = sub("tcp://", "", str_ssh)
# str_ssh = sub(":", " -p ", str_ssh)
# str_ssh = "ssh root@" + str_ssh
# print(str_ssh)
# print(f"ssh @6.tcp.ngrok.io -p")
# Out:
# Mounted at /content/drive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# we highly recommend that update your code by following this documentation https://github.com/WassimBenzarti/colab-ssh#getting-started
# Successfully running 2.tcp.ngrok.io:13385
# [Optional] You can also connect with VSCode SSH Remote extension using this configuration:
#
#   Host google_colab_ssh
#     HostName 2.tcp.ngrok.io
#     User root
#     Port 13385

# %%
# !nvidia-smi
# Out:
# Fri Nov  4 01:09:39 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %cd /content/drive/MyDrive/IITP/sohyun/TimeSeriesAnomaly/codes/for_serve
# !torchserve --start --model-store model_store --models lstmtest160.mar --ts-config configtest.properties

# %%
""
# Out:
# ''
